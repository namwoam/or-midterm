# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import os

mpl.rcParams['figure.dpi'] = 300


def sort_df(df: pd.DataFrame) -> pd.DataFrame:
    df = df.sort_values("Data name")
    df["len"] = df["Data name"].str.len()
    df = df.sort_values("len", kind="mergesort")
    df = df.reset_index()
    return df


optimal_solution = pd.read_csv("optimal_result.csv")

optimal_solution = sort_df(optimal_solution)

huristic_solution = pd.read_csv("jen_result.csv")

huristic_solution = sort_df(huristic_solution)

simple_solution =  pd.read_csv("simple_result.csv")

simple_solution = sort_df(simple_solution)

print(optimal_solution.head())
print(huristic_solution.head())
# Out:
#    index      Data name      Time  Profit  Feasibility  len
# 0    534  instance1.txt  0.241435   28640         True   13
# 1    935  instance2.txt  0.232612   53740         True   13
# 2    446  instance3.txt  0.248436   16400         True   13
# 3    613  instance4.txt  0.231967   17030         True   13
# 4    234  instance5.txt  0.249214   17600         True   13
#    index      Data name      Time  Profit  Feasibility  len
# 0    534  instance1.txt  0.000549     140         True   13
# 1    935  instance2.txt  0.000608   53740         True   13
# 2    446  instance3.txt  0.000888  -20920         True   13
# 3    613  instance4.txt  0.000545   17030         True   13
# 4    234  instance5.txt  0.000628  -21310         True   13

# %%
for subtask in range(5):
    f = plt.figure(subtask)
    plt.plot(optimal_solution['Profit'][subtask*100:(subtask+1)*100], label='Optimal')
    plt.plot(huristic_solution['Profit'][subtask*100:(subtask+1)*100], label='Complex Heuristic')
    plt.plot(simple_solution['Profit'][subtask*100:(subtask+1)*100], label='Simple Heuristic')
# add labels and title
    plt.xlabel('Index')
    plt.ylabel('Profit')
    plt.title(f'Profit Comparison, subtask-{subtask+1}')

    # add legend    
    plt.legend()

    # show the plot
    plt.savefig(f"subtask-{subtask+1}.png")
